# %% [markdown]
# <a href="https://www.kaggle.com/code/rohanambad/end-to-end-deployment-of-zomato-restaurant-ratings?scriptVersionId=105151375" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>
